# %% [markdown]
# # Source
#
# nathancy at Stackoverflow
# (https://stackoverflow.com/users/11162165/nathancy)

# %%
import cv2
import sys
import numpy as np

def nothing(x):
    pass

# Load in image
image = cv2.imread('Wound4.jpg')

# Create a window
cv2.namedWindow('image')

# create trackbars for color change
cv2.createTrackbar('HMin','image',0,179,nothing) # Hue is from 0-179 for Opencv
cv2.createTrackbar('SMin','image',0,255,nothing)
cv2.createTrackbar('VMin','image',0,255,nothing)
cv2.createTrackbar('HMax','image',0,179,nothing)
cv2.createTrackbar('SMax','image',0,255,nothing)
cv2.createTrackbar('VMax','image',0,255,nothing)

# Set default value for MAX HSV trackbars.
cv2.setTrackbarPos('HMax', 'image', 179)
cv2.setTrackbarPos('SMax', 'image', 255)
cv2.setTrackbarPos('VMax', 'image', 255)

# Initialize to check if HSV min/max value changes
hMin = sMin = vMin = hMax = sMax = vMax = 0
phMin = psMin = pvMin = phMax = psMax = pvMax = 0

output = image
wait_time = 33

while(1):

    # get current positions of all trackbars
    hMin = cv2.getTrackbarPos('HMin','image')
    sMin = cv2.getTrackbarPos('SMin','image')
    vMin = cv2.getTrackbarPos('VMin','image')

    hMax = cv2.getTrackbarPos('HMax','image')
    sMax = cv2.getTrackbarPos('SMax','image')
    vMax = cv2.getTrackbarPos('VMax','image')

    # Set minimum and max HSV values to display
    lower = np.array([hMin, sMin, vMin])
    upper = np.array([hMax, sMax, vMax])

    # Create HSV Image and threshold into a range.
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    mask = cv2.inRange(hsv, lower, upper)
    output = cv2.bitwise_and(image,image, mask= mask)

    # Print if there is a change in HSV value
    if( (phMin != hMin) | (psMin != sMin) | (pvMin != vMin) | (phMax != hMax) | (psMax != sMax) | (pvMax != vMax) ):
        print("(hMin = %d , sMin = %d, vMin = %d), (hMax = %d , sMax = %d, vMax = %d)" % (hMin , sMin , vMin, hMax, sMax , vMax))
        phMin = hMin
        psMin = sMin
        pvMin = vMin
        phMax = hMax
        psMax = sMax
        pvMax = vMax

    # Display output image
    cv2.imshow('image',output)

    # Wait longer to prevent freeze for videos.
    if cv2.waitKey(wait_time) & 0xFF == ord('q'):
        break

cv2.destroyAllWindows()
# Out:
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 3 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 1 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 3 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 6 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 14 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 20 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 22 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 26 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 28 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 33 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 37 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 42 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 48 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 55 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 61 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 70 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 73 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 74 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 75 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 86 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 96 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 106 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 112 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 123 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 130 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 140 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 151 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 162 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 164 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 165 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 167 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 169 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 170 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 172 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 173 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 163 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 149 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 137 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 122 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 106 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 92 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 86 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 83 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 80 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 72 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 50 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 29 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 19 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 18 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 15 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 14 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 11 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 6 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 3 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 1 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 5, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 6, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 11, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 16, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 22, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 25, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 38, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 46, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 51, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 54, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 57, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 59, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 63, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 67, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 71, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 80, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 84, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 89, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 94, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 99, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 107, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 121, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 143, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 160, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 164, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 168, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 176, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 181, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 184, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 187, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 190, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 194, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 199, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 203, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 207, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 209, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 211, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 212, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 207, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 195, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 178, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 131, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 91, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 77, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 72, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 64, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 63, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 62, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 57, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 52, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 46, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 42, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 43, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 40, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 37, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 36, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 35, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 32, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 27, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 21, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 16, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 13, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 12, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 1, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 4), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 5), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 20), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 28), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 42), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 52), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 67), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 83), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 97), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 115), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 120), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 131), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 135), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 139), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 145), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 152), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 157), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 164), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 174), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 181), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 182), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 186), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 203), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 230), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 245), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 248), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 249), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 250), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 253), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 254), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 253), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 245), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 232), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 221), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 209), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 196), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 188), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 184), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 183), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 177), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 157), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 129), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 113), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 103), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 101), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 92), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 83), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 68), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 53), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 46), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 42), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 31), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 20), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 177 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 176 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 172 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 169 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 166 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 164 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 163 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 162 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 159 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 157 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 153 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 150 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 148 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 146 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 144 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 142 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 140 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 139 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 140 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 144 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 153 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 168 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 178 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 177 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 176 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 175 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 173 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 175 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 176 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 177 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 176 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 175 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 176 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 178 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 254, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 252, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 251, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 250, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 246, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 244, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 241, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 239, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 237, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 234, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 230, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 226, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 221, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 218, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 216, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 213, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 209, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 203, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 197, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 189, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 183, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 178, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 173, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 167, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 157, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 147, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 142, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 137, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 134, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 133, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 137, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 147, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 169, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 204, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 231, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 245, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 254, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 254)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 251)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 246)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 240)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 231)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 220)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 213)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 207)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 202)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 195)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 185)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 173)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 160)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 156)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 153)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 152)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 151)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 148)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 143)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 138)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 137)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 133)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 126)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 103)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 72)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 55)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 40)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 36)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 35)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 39)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 53)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 76)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 88)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 98)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 118)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 127)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 134)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 140)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 143)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 146)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 147)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 149)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 154)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 160)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 164)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 168)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 169)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 171)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 175)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 181)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 191)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 203)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 209)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 210)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 213)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 219)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 228)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 231)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 229)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 203)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 195)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 252, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 240, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 228, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 212, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 198, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 189, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 179, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 172, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 157, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 143, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 131, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 125, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 121, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 118, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 116, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 113, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 115, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 120, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 129, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 143, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 156, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 171, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 183, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 194, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 205, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 214, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 223, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 229, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 233, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 235, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 238, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 241, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 248, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 178 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 176 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 169 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 160 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 147 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 138 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 134 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 131 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 129 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 128 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 129 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 133 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 135 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 137 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 138 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 139 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 143 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 145 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 148 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 149 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 153 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 157 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 159 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 160 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 163 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 166 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 168 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 174 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 178 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 176 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 174 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 170 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 167 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 165 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 163 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 162 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 161 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 158 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 154 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 194)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 195)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 197)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 198)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 199)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 200)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 201)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 203)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 205)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 206)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 209)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 213)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 216)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 219)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 221)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 224)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 226)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 229)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 231)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 232)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 234)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 235)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 236)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 239)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 240)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 241)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 242)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 244)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 245)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 246)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 248)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 249)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 250)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 251)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 253)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 254)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 149 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 147 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 143 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 140 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 139 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 138 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 137 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 136 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 134 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 133 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 134 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 137 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 144 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 149 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 152 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 155 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 157 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 159 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 160 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 162 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 163 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 164 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 166 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 169 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 170 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 172 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 176 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 175 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 174 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 173 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 172 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 170 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 168 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 4, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 6, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 12, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 21, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 23, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 27, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 30, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 38, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 40, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 43, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 46, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 48, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 52, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 54, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 61, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 64, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 68, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 67, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 64, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 50, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 21, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 3 , sMin = 0, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 0, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 18 , sMin = 0, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 25 , sMin = 0, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 29 , sMin = 0, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 34 , sMin = 0, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 36 , sMin = 0, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 0, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 38 , sMin = 0, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 39 , sMin = 0, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 30 , sMin = 0, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 26 , sMin = 0, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 24 , sMin = 0, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 23 , sMin = 0, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 22 , sMin = 0, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 21 , sMin = 0, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 18 , sMin = 0, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 8 , sMin = 0, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 1 , sMin = 0, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 5), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 17), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 30), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 42), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 51), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 56), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 65), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 72), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 81), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 92), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 94), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 93), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 84), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 65), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 45), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 31), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 18), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 9), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 9), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 53), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 102), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 129), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 142), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 156), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 170), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 186), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 197), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 204), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 209), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 215), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 223), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 238), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 251), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 255), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 250), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 223), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 174), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 96), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 69), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 41), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 22), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 7), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
